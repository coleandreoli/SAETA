# %% [markdown]
# # Get Data

# %%
import numpy as np
import pandas as pd
import os
from roboflow import Roboflow

import fiftyone as fo
import fiftyone.zoo as foz
import fiftyone.utils.random as four
import pandas.api.types as pdt
from fiftyone import ViewField as F
from tqdm import tqdm

rf = Roboflow(api_key=os.environ.get("ROBOFLOW_API_KEY"))

# %%
# project = rf.workspace("suas-gyf9o").project("test-t0cxb")
# version = project.version(2)
# dataset = version.download(
#     "coco", "/home/cole/cole_scripts/vision/SAETA/datasets/drone"
# )
# project = rf.workspace("suas-gyf9o").project("tent-xwofm-2hmcv")
# version = project.version(2)
# dataset = version.download("coco", "/home/cole/cole_scripts/vision/SAETA/datasets/tent")

# %%
# fo.delete_dataset("2026_SUAS")

# %%
if "2026_SUAS" in fo.list_datasets():
    dataset = fo.load_dataset("2026_SUAS")
else:
    from convert_visdrone_to_yolo import load_datasets_from_dirs

    dataset = load_datasets_from_dirs("2026_SUAS", ["datasets/drone", "datasets/tent"])
df = dataset
print(dataset)
# Out:
# Loading train from datasets/2026_suas_v6/train...
#  100% |█████████████████████| 0/0 [7.8ms elapsed, ? remaining, ? samples/s]
# Loading valid from datasets/2026_suas_v6/valid...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 3
#       1 from convert_visdrone_to_yolo import load_datasets_from_dirs
# ----> 3 dataset = load_datasets_from_dirs("2026_suas_v6", ["datasets/2026_suas_v6"], persistent=True)
#       5 print(dataset)
#
# File ~/cole_scripts/vision/SAETA/convert_visdrone_to_yolo.py:171, in load_datasets_from_dirs(dataset_name, base_dirs, splits, persistent)
#     169 for data_path, labels_path, tag in all_splits:
#     170     print(f"Loading {tag} from {data_path}...")
# --> 171     dataset.add_dir(
#     172         dataset_type=fo.types.COCODetectionDataset,
#     173         data_path=data_path,
#     174         labels_path=labels_path,
# ...

# %% [markdown]
# # Clean Data

# %%
# Remove images without anotations
df = dataset.exists("detections")
classes = df.distinct("detections.detections.label")
print(f"Classes: {classes}")
print(df)
# Out:
# Classes: ['0', '1', '2', '4', 'tent']
# Dataset:     2026_SUAS
# Media type:  image
# Num samples: 8766
# Sample fields:
#     id:               fiftyone.core.fields.ObjectIdField
#     filepath:         fiftyone.core.fields.StringField
#     tags:             fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:         fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     created_at:       fiftyone.core.fields.DateTimeField
#     last_modified_at: fiftyone.core.fields.DateTimeField
#     detections:       fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     predictions:      fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     final:            fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
# View stages:
#     1. Exists(field='detections', bool=True)

# %%
# Load YOLO11m from FiftyOne zoo
model = foz.load_zoo_model("yolo11m-coco-torch")

# Filter for samples that contain tents
samples_with_tents = df.filter_labels("detections", F("label") == "tent").exists(
    "detections"
)

# Apply model ONLY to images with tents (this modifies the original dataset)
samples_with_tents.apply_model(model, label_field="predictions")
samples_with_tents = samples_with_tents.filter_labels(
    "predictions", F("label").is_in(["tent", "person"])
)
samples_with_tents.save()
# Out:
#  100% |█████████████████| 335/335 [13.1s elapsed, 0s remaining, 28.4 samples/s]

# %%
# from tqdm import tqdm

# def combine_detections(sample):
#     return [det for field in ["detections", "predictions"]
#             if field in sample and sample[field]
#             for det in sample[field].detections]

# for sample in tqdm(df.iter_samples(autosave=True), total=len(df)):
#     sample["final"] = fo.Detections(detections=combine_detections(sample))

# %%
# import concurrent.futures
# from tqdm import tqdm
# import fiftyone as fo

# def combine_detections(sample):
#     all_detections = []

#     for field_name in ["detections", "predictions"]:
#         if field_name in sample and sample[field_name] is not None:
#             all_detections.extend(sample[field_name].detections)

#     return all_detections

# def process_sample(sample):
#     combined_detections = combine_detections(sample)
#     sample["final"] = fo.Detections(detections=combined_detections)
#     sample.save()
#     return sample

# # Convert to list for concurrent processing
# samples = list(df.iter_samples())

# with concurrent.futures.ThreadPoolExecutor(max_workers=4) as executor:
#     list(tqdm(executor.map(process_sample, samples), total=len(samples)))

# %%
def combine_detections(sample):
    all_detections = []

    for field_name in ["detections", "predictions"]:
        if field_name in sample and sample[field_name] is not None:
            all_detections.extend(sample[field_name].detections)

    return all_detections


# Process in bulk - much faster!
for sample in tqdm(df):
    combined_detections = combine_detections(sample)
    sample["final"] = fo.Detections(detections=combined_detections)

# Single save operation for all samples
df.save()
# Out:
# 100%|██████████| 8766/8766 [04:35<00:00, 31.78it/s]

# %%
# from tqdm import tqdm

# for sample in tqdm(df):  # assuming 'dataset' is your FiftyOne dataset
#     all_detections = []

#     # Add detections from "detections" field
#     if "detections" in sample and sample["detections"] is not None:
#         all_detections.extend([det.copy() for det in sample["detections"].detections])

#     # Add detections from "predictions" field
#     if "predictions" in sample and sample["predictions"] is not None:
#         all_detections.extend([det.copy() for det in sample["predictions"].detections])

#     # Create final combined detections
#     sample["final"] = fo.Detections(detections=all_detections)
#     sample.save()

# %%
df = df.map_labels("final", {"0": "person"})
df = df.filter_labels("final", F("label").is_in(["tent", "person"]), only_matches=True)

# %%
has_both = df.match(
    (F("final.detections.label").contains("tent"))
    & (F("final.detections.label").contains("person"))
)
tents_only = df.match((F("final.detections.label").contains("tent")))
print(f"Samples with both tent AND person: {len(has_both)}")
print(f"Samples with tent ONLY: {len(tents_only)}")
# Out:
# Samples with both tent AND person: 183
# Samples with tent ONLY: 335

# %%
# weights = dataset.values(F("final.detections.label").contains("tent").strlen())

# %%
tf = (
    df.match(F("final.detections.label").contains("person"))
    .shuffle()
    .take(int(len(tents_only) / 10))
)
tf = tf.concat(df.match(F("final.detections.label").contains("tent")))
fo.CategoricalHistogram("final.detections.label", init_view=tf)
# Out:
# FigureWidget({
#     'data': [{'hovertemplate': '<b>label: %{x}</b><br>count: %{y}<extra></extra>',
#               'marker': {'color': '#FF6D04'},
#               'type': 'bar',
#               'uid': '7409b76b-9eff-43ce-9fd0-956c4eb19fdb',
#               'x': [person, tent],
#               'y': [1101, 741]}],
#     'layout': {'margin': {'b': 0, 'l': 0, 'r': 0, 't': 30},
#                'template': '...',
#                'xaxis': {'title': {'text': 'final.detections.label'}},
#                'yaxis': {'title': {'text': 'count'}}}
# })

# %%
fo.CategoricalHistogram("final.detections.label", init_view=df)
# Out:
# FigureWidget({
#     'data': [{'hovertemplate': '<b>label: %{x}</b><br>count: %{y}<extra></extra>',
#               'marker': {'color': '#FF6D04'},
#               'type': 'bar',
#               'uid': 'a12e6c4d-30a9-41d8-8378-f7b06291e780',
#               'x': [person, tent],
#               'y': [145167, 739]}],
#     'layout': {'margin': {'b': 0, 'l': 0, 'r': 0, 't': 30},
#                'template': '...',
#                'xaxis': {'title': {'text': 'final.detections.label'}},
#                'yaxis': {'title': {'text': 'count'}}}
# })

# %%
# session = fo.launch_app(df)

# %% [markdown]
# # Export

# %%
import fiftyone.utils.random as four
import yaml
from pathlib import Path

# 70/20/10 split - use "valid" directly
four.random_split(tf, {"train": 0.7, "test": 0.1, "val": 0.2})

# Export each split separately
base_dir = "/home/cole/cole_scripts/vision/SAETA/datasets/2026_suas_v6"

for split in ["train", "test", "val"]:
    print(f"Exporting {split}...")
    tf.match_tags(split).export(
        export_dir=f"{base_dir}/{split}",
        dataset_type=fo.types.YOLOv5Dataset,
        label_field="final",
        classes=["person", "tent"],
        yaml_path=None,
    )
    # dataset_yaml = Path(f"{base_dir}/{split}/dataset.yaml")
    # if dataset_yaml.exists():
    #     dataset_yaml.unlink()

# Create custom data.yaml
data_yaml = {
    "train": "../train/images",
    "val": "../val/images",
    "test": "../test/images",
    "nc": 2,
    "names": ["person", "tent"],
}

# Write data.yaml to base directory
with open(f"{base_dir}/data.yaml", "w") as f:
    yaml.dump(data_yaml, f, default_flow_style=False, sort_keys=False)

print(f"\nExport complete! Dataset saved to: {base_dir}")
# Out:
# Exporting train...
#  100% |█████████████████| 368/368 [6.5s elapsed, 0s remaining, 244.0 samples/s]
# Exporting test...
#  100% |█████████████████| 297/297 [4.3s elapsed, 0s remaining, 276.4 samples/s]
# Exporting val...
#  100% |█████████████████| 300/300 [4.4s elapsed, 0s remaining, 256.8 samples/s]
#
# Export complete! Dataset saved to: /home/cole/cole_scripts/vision/SAETA/datasets/2026_suas_v6

# %%
# !cd /home/cole/cole_scripts/vision/SAETA/datasets && zip -r "2026_suas_v6.zip" "2026_suas_v6"
# Out:
#   adding: 2026_suas_v6/ (stored 0%)
#   adding: 2026_suas_v6/train/ (stored 0%)
#   adding: 2026_suas_v6/train/labels/ (stored 0%)
#   adding: 2026_suas_v6/train/labels/val/ (stored 0%)
#   adding: 2026_suas_v6/train/labels/val/3_mp4-0009_jpg.rf.d79d5c0f997df5627bea7e5e9eb8b80e.txt (deflated 39%)
#   adding: 2026_suas_v6/train/labels/val/4400_jpg.rf.a5ef2bb269cd0ac7b227d303d71a35fb.txt (deflated 31%)
#   adding: 2026_suas_v6/train/labels/val/DJI_0108_MP4-27_jpg.rf.805e5595ff2e63541b3f086ae7c24abf.txt (deflated 46%)
#   adding: 2026_suas_v6/train/labels/val/1_mp4-0016_jpg.rf.6d094ee8ae6111cd27ae99a00ee92785.txt (deflated 16%)
#   adding: 2026_suas_v6/train/labels/val/37_jpeg_jpg.rf.a05428f178211937d53e70fd630e1740.txt (deflated 39%)
#   adding: 2026_suas_v6/train/labels/val/73ec886e8d2e4fb9_jpg.rf.dd2e9ad87e31fed6e3911ba06a14b503.txt (deflated 50%)
#   adding: 2026_suas_v6/train/labels/val/120_jpg.rf.2c0b905e686f51fca3f85121234375ed.txt (deflated 31%)
# ...

# %%
fo.CategoricalHistogram("final.detections.label", init_view=tf.match_tags("val"))
# Out:
# FigureWidget({
#     'data': [{'hovertemplate': '<b>label: %{x}</b><br>count: %{y}<extra></extra>',
#               'marker': {'color': '#FF6D04'},
#               'type': 'bar',
#               'uid': 'cf2099cb-42a0-42f8-a97f-fc14e0199627',
#               'x': [person, tent],
#               'y': [757, 409]}],
#     'layout': {'margin': {'b': 0, 'l': 0, 'r': 0, 't': 30},
#                'template': '...',
#                'xaxis': {'title': {'text': 'final.detections.label'}},
#                'yaxis': {'title': {'text': 'count'}}}
# })

# %%
# Export using the merged final_labels field
export_dir = "/home/cole/cole_scripts/vision/SAETA/datasets/2026_suas_v6_robo"
label_field = "final"
dataset_type = fo.types.YOLOv5Dataset

tf.export(
    export_dir=export_dir,
    dataset_type=dataset_type,
    label_field=label_field,
    classes=["person", "tent"],
)
# Out:
#  100% |█████████████████| 368/368 [5.4s elapsed, 0s remaining, 286.9 samples/s]

# %%
workspace = rf.workspace("suas-gyf9o")

workspace.upload_dataset(
    export_dir,
    "2026-suas-v6",
    num_workers=20,
    project_license="MIT",
    project_type="object-detection",
)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Created project suas-gyf9o/2026-suas-v6
# [UPLOADED] /home/cole/cole_scripts/vision/SAETA/datasets/2026_suas_v6_robo/images/val/02720733b2241665_jpg.rf.5ee6bec1fd7dc542dbe68a9efec95941.jpg (U7mOemtSvxfKGTHoujRf) [1.3s] / annotations = OK [0.9s]
# [UPLOADED] /home/cole/cole_scripts/vision/SAETA/datasets/2026_suas_v6_robo/images/val/0000045_01500_d_0000086_jpg.rf.37014c97923f43ef091cea7a8547f43d.jpg (wPHZL9MMTAlGq8gHOWHu) [1.6s] / annotations = OK [1.0s]
# [UPLOADED] /home/cole/cole_scripts/vision/SAETA/datasets/2026_suas_v6_robo/images/val/0000352_02941_d_0000554_jpg.rf.93e17708cd27123429252cba9840b6f8.jpg (jmY1pcNubincRpqqpCJy) [1.6s] / annotations = OK [1.1s]
# [ERR] /home/cole/cole_scripts/vision/SAETA/datasets/2026_suas_v6_robo/images/val/0363274026_png.rf.68917560fc9898eb98b290ef7aee919f.jpg ('str' object has no attribute 'get')
# ...
